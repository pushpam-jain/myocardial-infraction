# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import wfdb
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTENC
from sklearn.model_selection import StratifiedKFold

# %%
def collect_and_label(dataset): 
    

    df = pd.read_csv(dataset)
    alpha = df['scp_codes'].str.split("'").str[1].str[-2:]=='MI'  
    beta = df['scp_codes'].str.split("'").str[1]=='NORM'       
    df = df[alpha|beta]
    df['label'] = df['scp_codes'].str.split("'").str[1]      
      
    inst_c1 = df[df['label'] == 'NORM']
    inst_c1 = inst_c1.sample(n = 1000, random_state = 1)
    
    inst_c2 = df[df['label'] == 'ILMI']
    inst_c2 = inst_c2.sample(n = 393, random_state = 1)
    

    df_new = pd.concat([inst_c1, inst_c2], ignore_index = True)
    df_new = df_new.sample(frac = 1, random_state=42)
    
    return  df_new

# %%
def div_and_label(dataframe):  
    
    X = dataframe[['ecg_id', 'filename_hr']]   
    X = X.to_numpy()
    y = dataframe['label']
    encoder = LabelEncoder()
    encoder.fit(y)
    encoded_y = encoder.transform(y)
    
    return (X, encoded_y)

# %%
alpha = collect_and_label("C:/Users/Pushpam/Downloads/ptbxl_database.csv")  
gamma0, gamma1 = div_and_label(alpha)
gamma0 = gamma0[:,1]

print(gamma0.shape)
print(gamma1.shape)

# %%
print(gamma0)

# %%
gamma1

# %%
from scipy import signal
import matplotlib.pyplot as plt

# %%
import wfdb
import numpy as np
import matplotlib.pyplot as plt
import neurokit2 as nk
from scipy.signal import butter, filtfilt, detrend

directory = 'D:/Internship/MIDataset/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.1'

X = []
for itr in range(gamma0.shape[0]):
    record_name = str(gamma0[itr])
    
    signal, meta_val = wfdb.rdsamp(directory + '/' + record_name)
    value = signal.T
    ecg_signals = value

    X.append(detrend(ecg_signals))

# %%
X = np.array(X)
X.shape

# %%
y_data = gamma1;
print(y_data.shape)

# %%
# windowing X in xnew
# xnew = np.zeros((5*(X.shape[0]),12,1000))
xold = X
yold = y_data
xnew = []
ynew = []
patient_ids = []
for i in range(X.shape[0]):
    xnew.append(X[i,:,0:1000])
    xnew.append(X[i,:,1000:2000])
    xnew.append(X[i,:,2000:3000])
    xnew.append(X[i,:,3000:4000])
    xnew.append(X[i,:,4000:5000])
    for j in range(5):
        ynew.append(y_data[i])
        patient_ids.append(i)
xnew = np.array(xnew)
y_data = np.array(ynew)

# %%
from scipy.signal import coherence
from glob import glob
import scipy.io as sio
import scipy.signal as sig
from scipy.signal import coherence, hilbert 

cross_corr_matrices_list = []
coherence_matrices_list = []
pli_matrices_list = []
plv_matrices_list = []

for patient_data in xnew:
    cross_corr_matrix = np.zeros((12, 12))
    coherence_matrix = np.zeros((12, 12))
    pli_matrix = np.zeros((12, 12))
    plv_matrix = np.zeros((12, 12))

    
    for i in range(12):
        for j in range(i, 12):
            lead_i = patient_data[i]
            lead_j = patient_data[j]
            
            cross_corr = np.corrcoef(lead_i, lead_j)[0, 1]
            
            f, coh = coherence(lead_i, lead_j)  
            coherence_value = np.mean(coh)  # Storing the average coherence value
            
            
            analytic_i = hilbert(lead_i)
            analytic_j = hilbert(lead_j)
            
            phase_i = np.angle(analytic_i)
            phase_j = np.angle(analytic_j)
                    
            phase_diff = phase_i - phase_j
              
            pli = np.abs(np.mean(np.sign(np.sin(phase_diff))))
               
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))

            cross_corr_matrix[i, j] = cross_corr
            cross_corr_matrix[j, i] = cross_corr
        
            coherence_matrix[i, j] = coherence_value
            coherence_matrix[j, i] = coherence_value    
            
            pli_matrix[i, j] = pli
            pli_matrix[j, i] = pli
            
            plv_matrix[i, j] = plv
            plv_matrix[j, i] = plv
    
    
    cross_corr_matrices_list.append(cross_corr_matrix)  
    coherence_matrices_list.append(coherence_matrix)
    pli_matrices_list.append(pli_matrix)
    plv_matrices_list.append(plv_matrix)
    
def create_K(A_i, B_i, C_i, D_i):
    top_row = np.concatenate((A_i, B_i), axis=1)
    bottom_row = np.concatenate((C_i, D_i), axis=1)
    return np.concatenate((top_row, bottom_row), axis=0)

K_matrices=[]
for i in range(xnew.shape[0]):
    K_i = create_K(cross_corr_matrices_list[i], coherence_matrices_list[i], pli_matrices_list[i], plv_matrices_list[i])
    K_matrices.append(K_i)

# %%
# To load the matrices back in another script, you can use the following code:
loaded_data = np.load('matrices_data.npz')
cross_corr_loaded = loaded_data['cross_corr']
coherence_loaded = loaded_data['coherence']
pli_loaded = loaded_data['pli']
plv_loaded = loaded_data['plv']

ynew = np.load(r"ynew_ALMI_800+164_kernels5000.npy")
patient_ids = np.load(r"patient_ids_ILMI_1000+393.npy")

# %%
# t = np.array(K_matrices).reshape(X.shape[0],12,12,4)
# print(t.shape)

# %%
t = []
for i in range(ynew.shape[0]):
    t2 = []
    t2.append(cross_corr_loaded[i])
    t2.append(pli_loaded[i])
    t2.append(plv_loaded[i])
    t2.append(coherence_loaded[i])
    t.append(np.array(t2).reshape(12,12,4))
t = np.array(t)

# %%
t.shape
# Out:
# (6965, 12, 12, 4)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import scale

# %%
from tensorflow.keras.layers import Flatten, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D, AvgPool2D

# %%
patient_ids = np.array(patient_ids)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GroupKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GroupKFold
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import BinaryCrossentropy

# Assuming t is a list of 4 matrices, each of shape (12, 12)
# Combine the 4 matrices into a single 4-channel input
X_data = np.stack(t, axis=-1)

gkf = GroupKFold(n_splits=5)

sum_accuracy = 0
sum_sensitivity = 0
sum_specificity = 0

for train_idx, test_idx in gkf.split(t, ynew, groups=patient_ids):
    X_train, X_test = t[train_idx], t[test_idx]
    y_train, y_test = ynew[train_idx], ynew[test_idx]

    tf.keras.backend.clear_session()

    model = Sequential()

    # Use 4 input channels
    model.add(Conv2D(10, (3, 3), input_shape=(12, 12, 4)))
    model.add(MaxPool2D(pool_size=(2, 2)))
    model.add(Flatten())

    model.add(Dense(128, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=BinaryCrossentropy(),
                  optimizer=RMSprop(),
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
                        batch_size=16,
                        epochs=20,
                        verbose=1,
                        validation_split=0.25)

    predictions = model.predict(X_test)
    y_pred = np.round(predictions).astype(int).transpose()
    y_pred = y_pred[0]

    y_pred_majority = []
    for patient_idx in np.unique(patient_ids[test_idx]):
        segment_predictions = y_pred[patient_ids[test_idx] == patient_idx]
        majority_vote = np.bincount(segment_predictions).argmax()
        y_pred_majority.append(majority_vote)

    y_test_majority = []
    for patient_idx in np.unique(patient_ids[test_idx]):
        segment_predictions = y_test[patient_ids[test_idx] == patient_idx]
        majority_vote = np.bincount(segment_predictions).argmax()
        y_test_majority.append(majority_vote)

    accuracy = accuracy_score(y_test_majority, y_pred_majority)
    sum_accuracy += accuracy
    # Calculate confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_test_majority, y_pred_majority).ravel()

    # Calculate sensitivity and specificity
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    sum_sensitivity += sensitivity
    sum_specificity += specificity

    print(confusion_matrix(y_test_majority, y_pred_majority))
    print("Accuracy:", accuracy)
    print("Sensitivity:", sensitivity)
    print("Specificity:", specificity)

average_accuracy = sum_accuracy / 5
average_sensitivity = sum_sensitivity / 5
average_specificity = sum_specificity / 5

print("Average Accuracy:", average_accuracy)
print("Average Sensitivity:", average_sensitivity)
print("Average Specificity:", average_specificity)
# Out:
# Epoch 1/20
# 262/262 [==============================] - 1s 2ms/step - loss: 0.2977 - accuracy: 0.8702 - val_loss: 0.3811 - val_accuracy: 0.8478
# Epoch 2/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2174 - accuracy: 0.9124 - val_loss: 0.2560 - val_accuracy: 0.8909
# Epoch 3/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.9253 - val_loss: 0.2592 - val_accuracy: 0.9031
# Epoch 4/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1633 - accuracy: 0.9375 - val_loss: 0.2147 - val_accuracy: 0.9088
# Epoch 5/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1448 - accuracy: 0.9435 - val_loss: 0.2883 - val_accuracy: 0.8995
# Epoch 6/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9552 - val_loss: 0.2230 - val_accuracy: 0.9153
# Epoch 7/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1063 - accuracy: 0.9605 - val_loss: 0.2386 - val_accuracy: 0.9167
# Epoch 8/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9662 - val_loss: 0.2959 - val_accuracy: 0.9088
# Epoch 9/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9746 - val_loss: 0.2521 - val_accuracy: 0.9218
# Epoch 10/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0644 - accuracy: 0.9744 - val_loss: 0.2402 - val_accuracy: 0.9203
# Epoch 11/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0489 - accuracy: 0.9823 - val_loss: 0.2751 - val_accuracy: 0.9225
# Epoch 12/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0417 - accuracy: 0.9854 - val_loss: 0.3554 - val_accuracy: 0.9139
# Epoch 13/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0324 - accuracy: 0.9885 - val_loss: 0.4453 - val_accuracy: 0.8945
# Epoch 14/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0277 - accuracy: 0.9890 - val_loss: 0.3606 - val_accuracy: 0.9160
# Epoch 15/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 0.9938 - val_loss: 0.4315 - val_accuracy: 0.9124
# Epoch 16/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.3414 - val_accuracy: 0.9196
# Epoch 17/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.3870 - val_accuracy: 0.9196
# Epoch 18/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.9964 - val_loss: 0.4351 - val_accuracy: 0.9261
# Epoch 19/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.4425 - val_accuracy: 0.9160
# Epoch 20/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.4607 - val_accuracy: 0.9139
# 44/44 [==============================] - 0s 623us/step
# [[ 72  10]
#  [  9 188]]
# Accuracy: 0.931899641577061
# Sensitivity: 0.9543147208121827
# Specificity: 0.8780487804878049
# Epoch 1/20
# 262/262 [==============================] - 1s 2ms/step - loss: 0.3019 - accuracy: 0.8712 - val_loss: 0.2645 - val_accuracy: 0.8837
# Epoch 2/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2223 - accuracy: 0.9052 - val_loss: 0.2951 - val_accuracy: 0.8686
# Epoch 3/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1929 - accuracy: 0.9215 - val_loss: 0.2426 - val_accuracy: 0.8916
# Epoch 4/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1717 - accuracy: 0.9277 - val_loss: 0.2831 - val_accuracy: 0.8966
# Epoch 5/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1500 - accuracy: 0.9413 - val_loss: 0.2479 - val_accuracy: 0.8988
# Epoch 6/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1311 - accuracy: 0.9471 - val_loss: 0.3385 - val_accuracy: 0.8945
# Epoch 7/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1178 - accuracy: 0.9555 - val_loss: 0.3670 - val_accuracy: 0.8873
# Epoch 8/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1035 - accuracy: 0.9574 - val_loss: 0.3323 - val_accuracy: 0.9031
# Epoch 9/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0851 - accuracy: 0.9655 - val_loss: 0.4230 - val_accuracy: 0.8959
# Epoch 10/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0783 - accuracy: 0.9677 - val_loss: 0.3412 - val_accuracy: 0.8866
# Epoch 11/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0649 - accuracy: 0.9763 - val_loss: 0.3924 - val_accuracy: 0.9017
# Epoch 12/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0546 - accuracy: 0.9797 - val_loss: 0.3676 - val_accuracy: 0.8851
# Epoch 13/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0451 - accuracy: 0.9818 - val_loss: 0.4241 - val_accuracy: 0.8973
# Epoch 14/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0353 - accuracy: 0.9876 - val_loss: 0.4656 - val_accuracy: 0.8930
# Epoch 15/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 0.9890 - val_loss: 0.7188 - val_accuracy: 0.8844
# Epoch 16/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 0.9887 - val_loss: 0.4883 - val_accuracy: 0.8808
# Epoch 17/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.4995 - val_accuracy: 0.9045
# Epoch 18/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 0.9923 - val_loss: 0.5676 - val_accuracy: 0.9024
# Epoch 19/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 0.9928 - val_loss: 0.7385 - val_accuracy: 0.8945
# Epoch 20/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.7497 - val_accuracy: 0.8952
# 44/44 [==============================] - 0s 649us/step
# [[ 55  23]
#  [  5 196]]
# Accuracy: 0.899641577060932
# Sensitivity: 0.9751243781094527
# Specificity: 0.7051282051282052
# Epoch 1/20
# 262/262 [==============================] - 1s 2ms/step - loss: 0.3069 - accuracy: 0.8664 - val_loss: 0.6725 - val_accuracy: 0.7006
# Epoch 2/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2309 - accuracy: 0.9016 - val_loss: 0.3639 - val_accuracy: 0.8399
# Epoch 3/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9136 - val_loss: 0.2558 - val_accuracy: 0.8873
# Epoch 4/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.9253 - val_loss: 0.2934 - val_accuracy: 0.8894
# Epoch 5/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1620 - accuracy: 0.9356 - val_loss: 0.2639 - val_accuracy: 0.8880
# Epoch 6/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1464 - accuracy: 0.9394 - val_loss: 0.2760 - val_accuracy: 0.8923
# Epoch 7/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1269 - accuracy: 0.9526 - val_loss: 0.3083 - val_accuracy: 0.8995
# Epoch 8/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9574 - val_loss: 0.2747 - val_accuracy: 0.9002
# Epoch 9/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9653 - val_loss: 0.2979 - val_accuracy: 0.9045
# Epoch 10/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 0.9691 - val_loss: 0.3761 - val_accuracy: 0.8959
# Epoch 11/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0688 - accuracy: 0.9741 - val_loss: 0.3048 - val_accuracy: 0.8981
# Epoch 12/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0596 - accuracy: 0.9775 - val_loss: 0.3059 - val_accuracy: 0.8988
# Epoch 13/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9830 - val_loss: 0.3922 - val_accuracy: 0.8880
# Epoch 14/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9840 - val_loss: 0.3766 - val_accuracy: 0.8988
# Epoch 15/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9873 - val_loss: 0.3658 - val_accuracy: 0.8988
# Epoch 16/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9892 - val_loss: 0.4193 - val_accuracy: 0.9031
# Epoch 17/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.4182 - val_accuracy: 0.9081
# Epoch 18/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0191 - accuracy: 0.9928 - val_loss: 0.4627 - val_accuracy: 0.9060
# Epoch 19/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.5099 - val_accuracy: 0.9009
# Epoch 20/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.5016 - val_accuracy: 0.9017
# 44/44 [==============================] - 0s 626us/step
# [[ 76   9]
#  [  8 186]]
# Accuracy: 0.9390681003584229
# Sensitivity: 0.9587628865979382
# Specificity: 0.8941176470588236
# Epoch 1/20
# 262/262 [==============================] - 1s 2ms/step - loss: 0.3016 - accuracy: 0.8742 - val_loss: 0.2500 - val_accuracy: 0.9046
# Epoch 2/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2337 - accuracy: 0.9007 - val_loss: 0.2425 - val_accuracy: 0.9010
# Epoch 3/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2085 - accuracy: 0.9091 - val_loss: 0.2510 - val_accuracy: 0.9053
# Epoch 4/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1862 - accuracy: 0.9247 - val_loss: 0.2590 - val_accuracy: 0.9017
# Epoch 5/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 0.9311 - val_loss: 0.2664 - val_accuracy: 0.9010
# Epoch 6/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1424 - accuracy: 0.9436 - val_loss: 0.2704 - val_accuracy: 0.9082
# Epoch 7/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1335 - accuracy: 0.9479 - val_loss: 0.2985 - val_accuracy: 0.8974
# Epoch 8/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9546 - val_loss: 0.3094 - val_accuracy: 0.8974
# Epoch 9/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1010 - accuracy: 0.9596 - val_loss: 0.2859 - val_accuracy: 0.8917
# Epoch 10/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0865 - accuracy: 0.9684 - val_loss: 0.3659 - val_accuracy: 0.8895
# Epoch 11/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9708 - val_loss: 0.3082 - val_accuracy: 0.9024
# Epoch 12/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0661 - accuracy: 0.9763 - val_loss: 0.3588 - val_accuracy: 0.8960
# Epoch 13/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0531 - accuracy: 0.9811 - val_loss: 0.3923 - val_accuracy: 0.9053
# Epoch 14/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0469 - accuracy: 0.9813 - val_loss: 0.3822 - val_accuracy: 0.9046
# Epoch 15/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.9864 - val_loss: 0.4765 - val_accuracy: 0.9003
# Epoch 16/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9885 - val_loss: 0.4347 - val_accuracy: 0.8924
# Epoch 17/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0253 - accuracy: 0.9907 - val_loss: 0.4438 - val_accuracy: 0.8945
# Epoch 18/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 0.9919 - val_loss: 0.5082 - val_accuracy: 0.8867
# Epoch 19/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.5016 - val_accuracy: 0.9032
# Epoch 20/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.9950 - val_loss: 0.5023 - val_accuracy: 0.8981
# 44/44 [==============================] - 0s 638us/step
# [[ 61  13]
#  [ 11 193]]
# Accuracy: 0.9136690647482014
# Sensitivity: 0.946078431372549
# Specificity: 0.8243243243243243
# Epoch 1/20
# 262/262 [==============================] - 1s 2ms/step - loss: 0.2870 - accuracy: 0.8790 - val_loss: 0.2706 - val_accuracy: 0.8910
# Epoch 2/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.2119 - accuracy: 0.9182 - val_loss: 0.2566 - val_accuracy: 0.8960
# Epoch 3/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.9290 - val_loss: 0.3259 - val_accuracy: 0.8737
# Epoch 4/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1610 - accuracy: 0.9354 - val_loss: 0.4039 - val_accuracy: 0.8443
# Epoch 5/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1406 - accuracy: 0.9469 - val_loss: 0.3362 - val_accuracy: 0.8852
# Epoch 6/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1235 - accuracy: 0.9488 - val_loss: 0.2994 - val_accuracy: 0.8931
# Epoch 7/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.1083 - accuracy: 0.9581 - val_loss: 0.3087 - val_accuracy: 0.8881
# Epoch 8/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9646 - val_loss: 0.3882 - val_accuracy: 0.8780
# Epoch 9/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9711 - val_loss: 0.3195 - val_accuracy: 0.8945
# Epoch 10/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0681 - accuracy: 0.9754 - val_loss: 0.3642 - val_accuracy: 0.8974
# Epoch 11/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0551 - accuracy: 0.9806 - val_loss: 0.3691 - val_accuracy: 0.8981
# Epoch 12/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0462 - accuracy: 0.9852 - val_loss: 0.4406 - val_accuracy: 0.8938
# Epoch 13/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.9864 - val_loss: 0.4279 - val_accuracy: 0.8967
# Epoch 14/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9885 - val_loss: 0.4664 - val_accuracy: 0.8910
# Epoch 15/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0267 - accuracy: 0.9900 - val_loss: 0.5229 - val_accuracy: 0.8917
# Epoch 16/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.7035 - val_accuracy: 0.8795
# Epoch 17/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.5935 - val_accuracy: 0.8910
# Epoch 18/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.9950 - val_loss: 0.5923 - val_accuracy: 0.8910
# Epoch 19/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.7230 - val_accuracy: 0.8953
# Epoch 20/20
# 262/262 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.6804 - val_accuracy: 0.8945
# 44/44 [==============================] - 0s 628us/step
# [[ 57  17]
#  [  6 198]]
# Accuracy: 0.9172661870503597
# Sensitivity: 0.9705882352941176
# Specificity: 0.7702702702702703
# Average Accuracy: 0.9203089141589954
# Average Sensitivity: 0.960973730437248
# Average Specificity: 0.8143778454538856
